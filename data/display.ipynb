# %%
import pandas as pd

df = pd.read_csv('./applications.csv')
df.describe()
df.columns
# Out:
# C:\Users\Raven\AppData\Local\Temp\ipykernel_32136\1352986538.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./applications.csv')
# Index(['appid', 'name', 'type', 'is_free', 'release_date', 'required_age',
#        'short_description', 'supported_languages', 'header_image',
#        'background', 'metacritic_score', 'recommendations_total',
#        'mat_supports_windows', 'mat_supports_mac', 'mat_supports_linux',
#        'mat_final_price', 'mat_discount_percent', 'mat_currency', 'created_at',
#        'updated_at'],
#       dtype='object')

# %%
df_reviews = pd.read_csv('./reviews_final.csv')
df_reviews.describe()
df_reviews.columns
# Out:
# Index(['review_text', 'recommendationid', 'appid', 'author_steamid',
#        'author_num_games_owned', 'author_num_reviews', 'language',
#        'timestamp_created', 'timestamp_updated', 'voted_up', 'votes_up',
#        'votes_funny', 'weighted_vote_score', 'comment_count', 'steam_purchase',
#        'received_for_free', 'written_during_early_access', 'created_at',
#        'updated_at'],
#       dtype='object')

# %%
df_category = pd.read_csv('./categories.csv')
df_category.describe()
df_category.columns
# Out:
# Index(['id', 'name'], dtype='object')

# %%
df_category_to_app_link = pd.read_csv('./application_categories.csv')
df_category_to_app_link.describe()
df_category_to_app_link.columns
# Out:
# Index(['appid', 'category_id'], dtype='object')
